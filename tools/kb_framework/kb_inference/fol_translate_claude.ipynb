# %%
import json
import logging
import pandas as pd
from tqdm import tqdm
import random
import csv
from anthropic import Anthropic
import os
import time

import warnings
warnings.filterwarnings("ignore")

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
global_client = None

def load_llm():
    global global_client
    api_key = ""
    if not api_key:
        raise ValueError("ANTHROPIC_API_KEY environment variable must be set")
    global_client = Anthropic(api_key=api_key)
    logger.info("Claude API client initialized successfully!")

# %%
def load_knowledge_base(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def generate_queries(question, kb_file, properties_file, example_file):
    # Load knowledge base and properties
    kb_content = load_knowledge_base(kb_file)
    properties_content = load_knowledge_base(properties_file)
    example_content = load_knowledge_base(example_file)

    prompt = f"""
    You are an AI assistant tasked with generating queries for a first-order logic knowledge base using the AIMA Python library. Your task is to create a FOL query that can be used to answer the provided question.
    
    Question: {question}
    
    To understand how to translate and what are the available predicates, you can look into the following FOL predicates and statements.

    Knowledge Base Rules:
    {kb_content}

    Example of FOL related to object properties:
    {properties_content}

    Some more examples and explanations:
    TypeOf(x, Car)
    ColorOf(x, Red)

    Object properties take the type of vehicles and color. These can be retrieved from the question. But the color and type need
    to be capitalized, and any space in it should be removed. For example, a Police car should be PoliceCar. For PoliceCar you do not need to add ColorOf the police car in the FOL. But for other vehicles include ColorOf.

    Based on the knowledge base and object properties, generate a FOL query that would be necessary to answer the question. The queries should be in the format used by the AIMA Python library's fol_fc_ask function.

    Rules for generating queries:
    1. Each query should be a string that might be a conjunction of multiple predicates.
    2. Use 'x' as the variable name for the main object in question.
    3. The predicates should be combined to form a conjunctive query.
    4. Include predicates for type, attributes, and relevant relationships.
    5. Please do not use any predicate that is not present in the Knowledge Base Rules or Object Properties.
    6. Please use the predicates that are present in the rules. Please do not make any changes in predicates.
    7. Check the location of the object if the location is mentioned in the question.
    8. Questions that involve a single object should be responded to with a query which is a conjunction of some predicates.
    9. If the location of an object is not mentioned in the question then do not include InitialLocation or LastLocation predicates in the query.

    For example. For Location, use InitialLocation(x, position) or LastLocation(x, position) predicates. Don't use only Location(x). Then, create another list of actions between the two objects.

    Example 1:
    Question: "Is there a white car near the left?"
    Query: "TypeOf(x, Car)^ColorOf(x, White)^InitialLocation(x, NearLeft)"

    10. If the question involves two objects, then first generate the FOL query for each object similar to a single object question.
    11. Use 'y' as the variable name for the second object in the question.
    12. For two objects, the response would be the conjunction of all the predicates for both objects, which contains the predicates for the first object, the predicates for the second object, and the predicates for the interaction between them (if available).
    13. Only respond with the FOL query of the input question. Do not add any other text to it
    Example 2:
    Question: "Does the white car near the left come close to a pedestrian at the front?"
    Queries: "TypeOf(x, Car)^ColorOf(x, White)^InitialLocation(x, NearLeft)^Pedestrian(y)^InitialLocation(y, Front)^ComeClose(x, y)"

    Example 3:
    Question: "Can you spot a pedestrian walking near the right of the police car?"
    Queries: "Pedestrian(x)^Walk(x)^InitialLocation(x, NearRight)^TypeOf(y, PoliceCar)"

    Example 4:
    Question: "Can you spot a pedestrian walking near the right of the police car at the center?"
    Queries: "Pedestrian(x)^Walk(x)^InitialLocation(x, NearRight)^TypeOf(y, PoliceCar)^InitialLocation(x, Front)"

    Example 5:
    Question: "Is there a red car near the right?"
    Queries: "TypeOf(x, Car)^ColorOf(x, Red)^InitialLocation(x, Right)"

    In the above examples (example 3, 4), notice that both the examples mentioned about a police car. But in example 3, there was no mention of location of the police car, hence the FOL query does not include any location for the police car. But in the 4th example as there is a mention of the police car's position, we include it in the FOL query.

    Location can be any of the following: Left, NearLeft, FarLeft, Right, NearRight, FarRight, Front, NearFront, and FarFront. Please analyze the question
    Choose the proper one, and do not use any words other than the mentioned 9 for location. Do not use NearLeft, FarLeft, NearRight, FarRight, NearFront, and FarFront as the location predicate value if those are not mentioned explicitly in the question.
    Inside the location  predicates (InitialLocation, LastLocation) please don't use any other location other than these six: NearLeft, FarLeft, NearRight, FarRight, NearFront, and FarFront
    If a synonym is used in the question, try to find the closest one from the six mentioned positions.
    If you are not sure about the location/position of an object, seeing the question, don't include location predicates for that object.
    For example, the center can be replaced by NearFront.
    For location, we only have two predicates. Example: InitialLocation(x, NearLeft) and LastLocation(x, NearLeft)

    Please provide a FOL query for the given question. Ensure that the queriy cover all aspects necessary to answer the question based on the knowledge base and object properties.
    Also, please consider that some true predicates can lead other predicates to be true. For example: 

    ((Vehicles(x) & SpeedUp(x)) ==> Accelerate(x))
    ((Vehicles(x) & SpeedDown(x)) ==> Decelerate(x))
    (((Vehicles(x) & NotAccelerate(x)) & NotDecelerate(x)) ==> ConstantSpeed(x))

    Here, you do not need to check all the predicates (SpeedUp, SpeedDown, ConstantSpeed) to understand if a vehicle is moving at a constant speed.
    You can only check ConstantSpeed(x).
    
    Your response should be a query string. For example:
    "Predicate1(x, Value)^Predicate2(x)^Predicate3(x, OtherValue)"

    Respond with only the query string, no additional text.
    """

    # Here are more examples showing questions (Que) and their corresponding FOLs:
    # {example_content}

    response = global_client.messages.create(
        model="claude-3-5-sonnet-20241022",
        temperature=0.6,
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    
    return response.content[0].text

# %%
def write_to_file(file_path, question, queries):
    with open(file_path, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([question, queries])

def main():
    kb_file = "/home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/rules/all_rules.txt"
    properties_file = "/home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/rules/normal_vehicle_info_frequent_0001.txt"
    out_file_train = 'question_query_carla_claude.csv'
    example_file = 'example_translation_1.txt'
    
    load_llm()
    questions = pd.read_csv('../kitti_questions/all_que_fn.csv')['Questions'].fillna('')
    questions = [q for q in questions if q != '']
    
    # Check if output file exists and load already processed questions
    processed_questions = set()
    if os.path.exists(out_file_train):
        try:
            existing_data = pd.read_csv(out_file_train)
            processed_questions = set(existing_data['Question'].tolist())
            logger.info(f"Found {len(processed_questions)} already processed questions")
        except pd.errors.EmptyDataError:
            logger.info("Existing file is empty, processing all questions")
        except Exception as e:
            logger.error(f"Error reading existing file: {e}")
            logger.info("Creating new output file")
            processed_questions = set()
    
    # Filter out already processed questions
    remaining_questions = [q for q in questions if q not in processed_questions]
    logger.info(f"Processing {len(remaining_questions)} new questions")
    
    # Create file if it doesn't exist, or append if it exists
    if not os.path.exists(out_file_train):
        with open(out_file_train, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["Question", "FOL Query"])
    
    # Process remaining questions
    for i_cnt, question in enumerate(tqdm(remaining_questions)):
        try:
            queries = generate_queries(question, kb_file, properties_file, example_file)
            write_to_file(out_file_train, question, queries.replace('"', '').replace("'", ''))
        except Exception as e:
            logger.error(f"Error processing question '{question}': {e}")
            continue

        time.sleep(5)

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Claude API client initialized successfully!
# INFO:__main__:Found 373 already processed questions
# INFO:__main__:Processing 99 new questions
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                                  | 0/99 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 1/99 [00:06<10:38,  6.51s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 2/99 [00:12<10:24,  6.44s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 3/99 [00:19<10:24,  6.51s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 4/99 [00:25<10:08,  6.41s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 5/99 [00:32<10:28,  6.68s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 6/99 [00:39<10:27,  6.75s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 7/99 [00:46<10:22,  6.77s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 8/99 [00:52<10:03,  6.63s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                          | 9/99 [00:59<10:08,  6.77s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 10/99 [01:06<10:02,  6.76s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 11/99 [01:13<09:54,  6.75s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 12/99 [01:20<09:53,  6.82s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 13/99 [01:27<09:44,  6.80s/it]
# INFO:anthropic._base_client:Retrying request to /v1/messages in 0.426247 seconds                              | 14/99 [01:33<09:35,  6.77s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                       | 15/99 [03:51<1:04:51, 46.33s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 16/99 [03:58<47:30, 34.35s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 17/99 [04:04<35:24, 25.90s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 18/99 [04:11<27:12, 20.16s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 19/99 [04:18<21:48, 16.36s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 20/99 [04:25<17:41, 13.43s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 21/99 [04:31<14:43, 11.32s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 22/99 [04:38<12:41,  9.89s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 23/99 [04:44<11:11,  8.83s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 24/99 [04:52<10:23,  8.31s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 25/99 [04:58<09:34,  7.76s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 26/99 [05:04<08:55,  7.33s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 27/99 [05:11<08:32,  7.12s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 28/99 [05:18<08:19,  7.04s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 29/99 [05:24<07:58,  6.84s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 30/99 [05:30<07:39,  6.66s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 31/99 [05:37<07:22,  6.51s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 32/99 [05:44<07:30,  6.72s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 33/99 [05:50<07:22,  6.70s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 34/99 [05:58<07:29,  6.92s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 35/99 [06:05<07:24,  6.95s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 36/99 [06:12<07:16,  6.93s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 37/99 [06:18<07:04,  6.85s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 38/99 [06:25<06:57,  6.84s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 39/99 [06:33<07:02,  7.04s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 40/99 [06:40<06:53,  7.01s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 41/99 [06:46<06:37,  6.85s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 42/99 [06:53<06:29,  6.84s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 43/99 [07:00<06:31,  6.99s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 44/99 [07:07<06:15,  6.82s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 45/99 [07:13<06:04,  6.76s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 46/99 [07:20<05:51,  6.63s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 47/99 [07:27<05:52,  6.79s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 48/99 [07:33<05:41,  6.69s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 49/99 [07:40<05:36,  6.72s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 50/99 [07:47<05:31,  6.76s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 51/99 [07:55<05:40,  7.08s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 52/99 [08:01<05:27,  6.96s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 53/99 [08:08<05:14,  6.83s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 54/99 [08:15<05:06,  6.82s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 55/99 [08:22<05:04,  6.91s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 56/99 [08:29<04:57,  6.92s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 57/99 [08:35<04:46,  6.83s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 58/99 [08:42<04:38,  6.79s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 59/99 [08:49<04:32,  6.81s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 60/99 [08:55<04:20,  6.68s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 61/99 [09:02<04:12,  6.63s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 62/99 [09:09<04:05,  6.64s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 63/99 [09:15<04:00,  6.67s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 64/99 [09:22<03:50,  6.60s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 65/99 [09:30<03:56,  6.96s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 66/99 [09:36<03:44,  6.79s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 67/99 [09:43<03:36,  6.78s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 68/99 [09:49<03:28,  6.73s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 69/99 [09:57<03:31,  7.05s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 70/99 [10:03<03:17,  6.83s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 71/99 [10:10<03:12,  6.88s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 72/99 [10:17<03:03,  6.79s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 73/99 [10:24<02:56,  6.81s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 74/99 [10:31<02:50,  6.82s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"                         | 75/99 [10:38<02:44,  6.86s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"▌                        | 76/99 [10:45<02:39,  6.93s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"█▋                       | 77/99 [10:51<02:29,  6.80s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"██▋                      | 78/99 [10:58<02:22,  6.79s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"███▊                     | 79/99 [11:06<02:20,  7.01s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"████▊                    | 80/99 [11:13<02:16,  7.20s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"█████▉                   | 81/99 [11:20<02:07,  7.11s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"██████▉                  | 82/99 [11:27<01:57,  6.94s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"████████                 | 83/99 [11:33<01:49,  6.87s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"█████████                | 84/99 [11:40<01:42,  6.81s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"██████████▏              | 85/99 [11:46<01:33,  6.69s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"███████████▏             | 86/99 [11:53<01:26,  6.64s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"████████████▎            | 87/99 [12:00<01:22,  6.85s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"█████████████▎           | 88/99 [12:06<01:13,  6.66s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"██████████████▍          | 89/99 [12:13<01:06,  6.65s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"███████████████▍         | 90/99 [12:20<01:01,  6.87s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"████████████████▌        | 91/99 [12:27<00:53,  6.72s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"█████████████████▌       | 92/99 [12:34<00:48,  6.89s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"██████████████████▋      | 93/99 [12:40<00:40,  6.72s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"███████████████████▋     | 94/99 [12:49<00:35,  7.16s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"████████████████████▊    | 95/99 [12:55<00:28,  7.03s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"█████████████████████▊   | 96/99 [13:04<00:22,  7.38s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"██████████████████████▉  | 97/99 [13:13<00:15,  7.95s/it]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"███████████████████████▉ | 98/99 [13:20<00:07,  7.78s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 99/99 [13:29<00:00,  8.18s/it]

# %%
df = pd.read_csv('question_query.csv')

df = df.sample(frac=1).reset_index().drop(columns=['index'])

df_train = df.iloc[:470]
df_test = df.iloc[470:].reset_index().drop(columns=['index'])


df_train.to_csv('question_query_train.csv', index=False)
df_test.to_csv('question_query_test.csv', index=False)

# %%
import re

def extract_bracket_content(text):
    pattern = r'\[(.*?)\]'
    match = re.search(pattern, text)
    if match:
        return match.group(1).strip('"')
    return None

# %%
import requests
import json

api_url = "http://127.0.0.1:8899/v1/judge"
headers = {
    "Content-Type": "application/json",
    "X-API-Key": "147728a9-29dc-4260-af88-664915c717c1"
}
data = {
    "prompt": f"Does the black SUV on the left move at a constant speed?=TypeOf(x, SUV)^ColorOf(x, Black)^ConstantSpeed(x)",
    "max_new_tokens": 512,
    "temperature": 0.7,
    "do_sample":True,
    "temperature":0.6,
    "top_p":0.9,
}

response = requests.post(api_url, headers=headers, data=json.dumps(data))
response.raise_for_status()
result = response.json()["choices"][0]["text"].strip()

result
# Out:
# 'ROUGE-L F1: 1.00'

# %%
from rouge import Rouge
rouge = Rouge()

scores = rouge.get_scores(
    "TypeOf(x, SUV)^ColorOf(x, Black)^ConstantSpeed(x)^TypeOf(y, Car)^ColorOf(y, Blue)^InitialLocation(y, Right)", 
    "TypeOf(x, SUV)^ColorOf(x, Black)^ConstantSpeed(x)"
)
scores[0]
# Out:
# {'rouge-1': {'r': 0.6666666666666666,
#   'p': 0.3333333333333333,
#   'f': 0.44444444000000005},
#  'rouge-2': {'r': 0.5, 'p': 0.2, 'f': 0.2857142816326531},
#  'rouge-l': {'r': 0.6666666666666666,
#   'p': 0.3333333333333333,
#   'f': 0.44444444000000005}}

# %%
import numpy as np

# Create a sample 2D array
arr = np.array([
    [1, 5, 3],
    [4, 2, 6],
    [7, 8, 9],
    [10, 11, 12]
])

# Get the maximum of each row
row_maxima = np.max(arr, axis=0)

print("Original array:")
print(arr)
print("\nMaximum of each row:")
print(row_maxima, row_maxima.sum(), row_maxima.mean())
arr.shape, arr[1, 2]
# Out:
# Original array:
# [[ 1  5  3]
#  [ 4  2  6]
#  [ 7  8  9]
#  [10 11 12]]
#
# Maximum of each row:
# [10 11 12] 33 11.0
# ((4, 3), 6)
