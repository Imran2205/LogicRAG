# %%
import os
import pandas as pd
import numpy as np
import glob
import base64
import anthropic
from typing import List, Dict, Tuple
import time
import ast
import re
import logging
from datetime import datetime

# MODEL_NAME = "claude-3-5-sonnet-20240620"
# MODEL_NAME = "claude-3-5-sonnet-20241022"
MODEL_NAME = "claude-3-7-sonnet-20250219"

# Configure logging
def setup_logging(log_dir):
    """Set up logging with timestamp in filename"""
    os.makedirs(log_dir, exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    log_file = os.path.join(log_dir, f"{MODEL_NAME}_qa_log_{timestamp}.txt")
    
    # Configure logger
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler(log_file),
            logging.StreamHandler()  # Also print to console
        ]
    )
    
    return logging.getLogger()

def encode_image(image_path):
    """Encode an image to base64 string"""
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

def get_frames_for_range(video_name, frame_range, frames_dir, num_frames=5, logger=None):
    """Get equally spaced frames from a frame range"""
    start_frame, end_frame = map(int, frame_range.split('-'))
    all_frames = list(range(start_frame, end_frame + 1))
    
    # Select equally spaced frames
    if len(all_frames) <= num_frames:
        selected_indices = all_frames
    else:
        # This ensures we get the start, end, and equally spaced frames in between
        selected_indices = np.linspace(0, len(all_frames)-1, num_frames, dtype=int)
        selected_indices = [all_frames[i] for i in selected_indices]
    
    # Get the image paths
    frame_paths = []
    for frame_idx in selected_indices:
        frame_path = os.path.join(frames_dir, video_name, f"{frame_idx:06d}.png")
        if os.path.exists(frame_path):
            frame_paths.append(frame_path)
        else:
            if logger:
                logger.warning(f"Frame {frame_idx:06d} not found for video {video_name}")
            else:
                print(f"Warning: Frame {frame_idx:06d} not found for video {video_name}")
    
    return frame_paths

def generate_answers(images: List[str], questions: List[str], client, logger) -> List[str]:
    """Query Claude with the images and questions to get answers"""
    image_contents = [encode_image(img) for img in images]
    
    prompt = f"""
    Here is a sequence of 5 frames extracted from a video. The frames are consecutive frames from a video and thus contain temporal information. The camera is positioned at the center in first-person view. 
    Your task is to:
    1. Analyze the images provided and answer the given question.
    2. Answer each question accurately based on the images.
    3. Provide concise and clear answers.
    Questions:
    {questions}
    Please provide your answers in a list format, where each answer corresponds to the question in the same order. The answer should be either Yes or No.
    Your response should be a Python list of strings, each string being an answer. For example:
    ["Answer to question 1", "Answer to question 2", "Answer to question 3"]
    The example of value would be: ["Yes", "No", "Yes"]
    Respond with only the Python list of answers, no additional text.
    """
    
    logger.info(f"Sending prompt to Claude with {len(questions)} questions: {questions}")
    
    max_retries = 3
    retries = 0
    
    while retries < max_retries:
        try:
            message = client.messages.create(
                model=MODEL_NAME,
                max_tokens=2000,
                temperature=0,
                messages=[
                    {
                        "role": "user",
                        "content": [
                            {"type": "text", "text": prompt},
                            *[{"type": "image", "source": {"type": "base64", "media_type": "image/png", "data": img}} for img in image_contents]
                        ]
                    }
                ]
            )
            
            content = message.content[0].text
            logger.info(f"Claude's raw response: {content}")
            
            # Try to evaluate as a Python list
            try:
                # First, try direct eval
                answers = ast.literal_eval(content)
                if isinstance(answers, list) and all(isinstance(a, str) for a in answers):
                    logger.info(f"Successfully parsed answers: {answers}")
                    return answers
                else:
                    raise ValueError("Not a list of strings")
            except:
                # If that fails, try regex to extract a list pattern
                list_pattern = r'\[(.*?)\]'
                match = re.search(list_pattern, content, re.DOTALL)
                if match:
                    items = match.group(1).split(',')
                    answers = [item.strip().strip('"\'') for item in items]
                    if len(answers) == len(questions):
                        logger.info(f"Extracted answers using regex: {answers}")
                        return answers
                
                logger.warning(f"Retry {retries+1}: Could not parse Claude's response.")
                retries += 1
                time.sleep(2)  # Wait a bit before retrying
        
        except anthropic.APIError as e:
            logger.error(f"Anthropic API Error: {str(e)}")
            retries += 1
            time.sleep(5)  # Longer wait for API errors
    
    # If we've exhausted retries, return empty list
    logger.error("Failed to get valid response after maximum retries")
    return []

def convert_yes_no_to_binary(answers, logger):
    """Convert 'Yes'/'No' answers to 1/0"""
    binary_answers = []
    
    for answer in answers:
        answer = answer.strip().lower()
        if 'yes' in answer:
            binary_answers.append(1)
        else:
            binary_answers.append(0)
    
    logger.info(f"Converted answers to binary: {binary_answers}")        
    return binary_answers

def process_questions_csv(csv_path, frames_dir, output_csv_path, log_dir):
    """Process all questions in the CSV file"""
    # Set up logging
    logger = setup_logging(log_dir)
    logger.info(f"Starting processing of questions from {csv_path}")
    
    # Read the CSV file
    df = pd.read_csv(csv_path)
    logger.info(f"Loaded CSV with {len(df)} rows")
    
    # Initialize Anthropic client
    client = anthropic.Anthropic()
    
    # Add Claude column if it doesn't exist
    if MODEL_NAME not in df.columns:
        df[MODEL_NAME] = ""  # np.nan
        logger.info(f"Added '{MODEL_NAME}' column to DataFrame")
    
    # Group by Video and Frame
    groups = df.groupby(['Video', 'Frame'], dropna=False)
    logger.info(f"Found {len(groups)} unique video/frame groups")
    
    for (vid, frame_range), group in groups:
        video = f"{int(vid):04d}"
        if pd.isna(video) or pd.isna(frame_range):
            continue
            
        logger.info(f"Processing video {video}, frames {frame_range}")
        
        # Get the questions for this frame range
        questions = group['Questions'].tolist()
        logger.info(f"Questions: {questions}")
        
        # Get frame paths
        frame_paths = get_frames_for_range(video, frame_range, frames_dir, logger=logger)

        # print(vid, frame_range, frame_paths)
        # continue
        
        if not frame_paths or len(frame_paths) == 0:
            logger.error(f"No frames found for video {video}, frame range {frame_range}")
            continue
            
        logger.info(f"Using {len(frame_paths)} frames: {[os.path.basename(p) for p in frame_paths]}")
        
        # Generate answers
        answers = generate_answers(frame_paths, questions, client, logger)
        
        if not answers or len(answers) != len(questions):
            logger.error(f"Error: Did not get valid answers for video {video}, frame range {frame_range}")
            continue
            
        # Convert to binary
        binary_answers = convert_yes_no_to_binary(answers, logger)
        
        # Update the DataFrame
        idx = group.index
        df.loc[idx, MODEL_NAME] = [str(int(b_a)) for b_a in binary_answers]
        
        # Save after each group to preserve progress
        df.to_csv(output_csv_path, index=False)
        logger.info(f"Saved progress to {output_csv_path}")
        
        logger.info(f"Completed {video} {frame_range}. Answers: {answers}")
        logger.info(f"Binary: {binary_answers}")
        
        # Wait a bit to avoid rate limits
        time.sleep(1)
    
    # Final save
    df['Video'] = [f"{int(vd):04d}" for vd in df['Video']]
    df.to_csv(output_csv_path, index=False)
    logger.info(f"All processing complete. Results saved to {output_csv_path}")

# %%
import argparse
    
# parser = argparse.ArgumentParser(description="Process video frame questions with Claude")
# parser.add_argument("--csv", required=True, help="Path to input CSV file with questions")
# parser.add_argument("--frames_dir", required=True, help="Directory containing video frames")
# parser.add_argument("--output", required=True, help="Path to output CSV file")

csv = "/home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv"
frames_dir = "/data/datasets/KITTI/STEP/testing/image_02"
output = "/home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv"
log_dir = "/home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kb_inference/log_dir"
# args = parser.parse_args()

process_questions_csv(csv, frames_dir, output, log_dir)
# Out:
# 2025-02-28 03:01:40,240 - INFO - Starting processing of questions from /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:01:40,244 - INFO - Loaded CSV with 101 rows
# 2025-02-28 03:01:40,293 - INFO - Added 'claude-3-7-sonnet-20250219' column to DataFrame
# 2025-02-28 03:01:40,295 - INFO - Found 19 unique video/frame groups
# 2025-02-28 03:01:40,296 - INFO - Processing video 0000, frames 000060-000069
# 2025-02-28 03:01:40,297 - INFO - Questions: ['Can you spot a pedestrian at the right in the last few frames?', 'Is there a White Car on the right of the frame?', 'Does the distance between the pedestrian and the White Car remains constant?', 'Is there a Black Car on the left the scene?', 'Does the Black Car disappear from the scene?', 'Is there a Black Car on the left of the scene?', 'Is there a White Car on the left of the scene?']
# 2025-02-28 03:01:40,297 - INFO - Using 5 frames: ['000060.png', '000062.png', '000064.png', '000066.png', '000069.png']
# 2025-02-28 03:01:40,308 - INFO - Sending prompt to Claude with 7 questions: ['Can you spot a pedestrian at the right in the last few frames?', 'Is there a White Car on the right of the frame?', 'Does the distance between the pedestrian and the White Car remains constant?', 'Is there a Black Car on the left the scene?', 'Does the Black Car disappear from the scene?', 'Is there a Black Car on the left of the scene?', 'Is there a White Car on the left of the scene?']
# 2025-02-28 03:01:42,416 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:01:42,427 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "Yes", "No", "Yes", "No"]
# 2025-02-28 03:01:42,428 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No']
# 2025-02-28 03:01:42,429 - INFO - Converted answers to binary: [1, 1, 1, 1, 0, 1, 0]
# 2025-02-28 03:01:42,434 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:01:42,435 - INFO - Completed 0000 000060-000069. Answers: ['Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No']
# 2025-02-28 03:01:42,436 - INFO - Binary: [1, 1, 1, 1, 0, 1, 0]
# 2025-02-28 03:01:43,437 - INFO - Processing video 0000, frames 000180-000189
# 2025-02-28 03:01:43,438 - INFO - Questions: ['Is there a Black Car on the left of the scene?', 'Is the Black Car stopped?', 'Can you spot a Black Car on the left that disappear from the scene?', 'Is there a Black Car on the right?', 'Does the distance between the Black Car on the left and the Black Car on the right remains the same?']
# 2025-02-28 03:01:43,440 - INFO - Using 5 frames: ['000180.png', '000182.png', '000184.png', '000186.png', '000189.png']
# 2025-02-28 03:01:43,452 - INFO - Sending prompt to Claude with 5 questions: ['Is there a Black Car on the left of the scene?', 'Is the Black Car stopped?', 'Can you spot a Black Car on the left that disappear from the scene?', 'Is there a Black Car on the right?', 'Does the distance between the Black Car on the left and the Black Car on the right remains the same?']
# 2025-02-28 03:01:45,714 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:01:45,716 - INFO - Claude's raw response: ["Yes", "Yes", "No", "Yes", "Yes"]
# 2025-02-28 03:01:45,717 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'No', 'Yes', 'Yes']
# 2025-02-28 03:01:45,718 - INFO - Converted answers to binary: [1, 1, 0, 1, 1]
# 2025-02-28 03:01:45,722 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:01:45,722 - INFO - Completed 0000 000180-000189. Answers: ['Yes', 'Yes', 'No', 'Yes', 'Yes']
# 2025-02-28 03:01:45,723 - INFO - Binary: [1, 1, 0, 1, 1]
# 2025-02-28 03:01:46,724 - INFO - Processing video 0000, frames 000450-000459
# 2025-02-28 03:01:46,726 - INFO - Questions: ['Is there a Black Car near the left that disappears from the scene?', 'Can you spot a trafficsign near the left?', 'Can you spot a pole in the front that shifts to the right at the  last few frames?', 'Can you spot a White Car near the right?', 'Can you spot a Black Car in the front?', 'Does the distance between the White Car on the right and the Black Car in the front remains the same?', 'Is the White Car on the right stopped?']
# 2025-02-28 03:01:46,727 - INFO - Using 5 frames: ['000450.png', '000452.png', '000454.png', '000456.png', '000459.png']
# 2025-02-28 03:01:46,741 - INFO - Sending prompt to Claude with 7 questions: ['Is there a Black Car near the left that disappears from the scene?', 'Can you spot a trafficsign near the left?', 'Can you spot a pole in the front that shifts to the right at the  last few frames?', 'Can you spot a White Car near the right?', 'Can you spot a Black Car in the front?', 'Does the distance between the White Car on the right and the Black Car in the front remains the same?', 'Is the White Car on the right stopped?']
# 2025-02-28 03:01:48,594 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:01:48,596 - INFO - Claude's raw response: ["No", "Yes", "Yes", "Yes", "Yes", "No", "Yes"]
# 2025-02-28 03:01:48,597 - INFO - Successfully parsed answers: ['No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes']
# 2025-02-28 03:01:48,600 - INFO - Converted answers to binary: [0, 1, 1, 1, 1, 0, 1]
# 2025-02-28 03:01:48,604 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:01:48,605 - INFO - Completed 0000 000450-000459. Answers: ['No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes']
# 2025-02-28 03:01:48,605 - INFO - Binary: [0, 1, 1, 1, 1, 0, 1]
# 2025-02-28 03:01:49,607 - INFO - Processing video 0001, frames 000000-000009
# 2025-02-28 03:01:49,609 - INFO - Questions: ['Is there a Black Car in the front in the initial frames that moves to the right?', 'Does the Black Car move at a constant speed?', 'Can you spot a White Car on the left of the scene?', 'Does the White Car on the left move at a constant speed?', 'Does the distance between the Black Car and the White Car remains the same?', 'Can you spot a trafficsign near the left?', 'Can you spot a trafficlight near the left?', 'Can you spot a pedestrian on the left?']
# 2025-02-28 03:01:49,610 - INFO - Using 5 frames: ['000000.png', '000002.png', '000004.png', '000006.png', '000009.png']
# 2025-02-28 03:01:49,622 - INFO - Sending prompt to Claude with 8 questions: ['Is there a Black Car in the front in the initial frames that moves to the right?', 'Does the Black Car move at a constant speed?', 'Can you spot a White Car on the left of the scene?', 'Does the White Car on the left move at a constant speed?', 'Does the distance between the Black Car and the White Car remains the same?', 'Can you spot a trafficsign near the left?', 'Can you spot a trafficlight near the left?', 'Can you spot a pedestrian on the left?']
# 2025-02-28 03:01:51,610 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:01:51,613 - INFO - Claude's raw response: ["No", "No", "Yes", "Yes", "No", "Yes", "Yes", "No"]
# 2025-02-28 03:01:51,613 - INFO - Successfully parsed answers: ['No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No']
# 2025-02-28 03:01:51,614 - INFO - Converted answers to binary: [0, 0, 1, 1, 0, 1, 1, 0]
# 2025-02-28 03:01:51,617 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:01:51,618 - INFO - Completed 0001 000000-000009. Answers: ['No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No']
# 2025-02-28 03:01:51,619 - INFO - Binary: [0, 0, 1, 1, 0, 1, 1, 0]
# 2025-02-28 03:01:52,621 - INFO - Processing video 0001, frames 000010-000019
# 2025-02-28 03:01:52,622 - INFO - Questions: ['Can you spot a Black Car on the right of the scene?', 'Does the Black Car disappear from the right of the scene?', 'Does a White Car appear on the left of the scene?', 'Does the White Car move at a constant speed?']
# 2025-02-28 03:01:52,623 - INFO - Using 5 frames: ['000010.png', '000012.png', '000014.png', '000016.png', '000019.png']
# 2025-02-28 03:01:52,636 - INFO - Sending prompt to Claude with 4 questions: ['Can you spot a Black Car on the right of the scene?', 'Does the Black Car disappear from the right of the scene?', 'Does a White Car appear on the left of the scene?', 'Does the White Car move at a constant speed?']
# 2025-02-28 03:01:54,477 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:01:54,479 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "Yes"]
# 2025-02-28 03:01:54,480 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'Yes']
# 2025-02-28 03:01:54,480 - INFO - Converted answers to binary: [1, 1, 1, 1]
# 2025-02-28 03:01:54,484 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:01:54,485 - INFO - Completed 0001 000010-000019. Answers: ['Yes', 'Yes', 'Yes', 'Yes']
# 2025-02-28 03:01:54,486 - INFO - Binary: [1, 1, 1, 1]
# 2025-02-28 03:01:55,488 - INFO - Processing video 0001, frames 000020-000029
# 2025-02-28 03:01:55,489 - INFO - Questions: ['Is there a White Car on the left?', 'Does a Black Car appear from the left?', 'Does a Red Car appear from the left?', 'Does the distance between the White Car and the Red Car increase?', 'Does the distance between the White Car and the Red Car decrease?']
# 2025-02-28 03:01:55,490 - INFO - Using 5 frames: ['000020.png', '000022.png', '000024.png', '000026.png', '000029.png']
# 2025-02-28 03:01:55,502 - INFO - Sending prompt to Claude with 5 questions: ['Is there a White Car on the left?', 'Does a Black Car appear from the left?', 'Does a Red Car appear from the left?', 'Does the distance between the White Car and the Red Car increase?', 'Does the distance between the White Car and the Red Car decrease?']
# 2025-02-28 03:01:58,867 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:01:58,869 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "No", "Yes"]
# 2025-02-28 03:01:58,870 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'No', 'Yes']
# 2025-02-28 03:01:58,871 - INFO - Converted answers to binary: [1, 1, 1, 0, 1]
# 2025-02-28 03:01:58,875 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:01:58,876 - INFO - Completed 0001 000020-000029. Answers: ['Yes', 'Yes', 'Yes', 'No', 'Yes']
# 2025-02-28 03:01:58,877 - INFO - Binary: [1, 1, 1, 0, 1]
# 2025-02-28 03:01:59,879 - INFO - Processing video 0002, frames 000000-000009
# 2025-02-28 03:01:59,880 - INFO - Questions: ['Can you spot a Gray Car near the left?', 'Can you spot a Black Car on the left?', 'Can you spot a Black Car at the front?', 'Does the Gray Car on the left disappear from the scene?', 'Does the distance between Gray Car on the left and the Black Car in the front increase?', 'Can you spot a building in the front?', 'Can you spot a trafficsign in the front that shifts to the right in the later frames due to the camera movement?']
# 2025-02-28 03:01:59,881 - INFO - Using 5 frames: ['000000.png', '000002.png', '000004.png', '000006.png', '000009.png']
# 2025-02-28 03:01:59,893 - INFO - Sending prompt to Claude with 7 questions: ['Can you spot a Gray Car near the left?', 'Can you spot a Black Car on the left?', 'Can you spot a Black Car at the front?', 'Does the Gray Car on the left disappear from the scene?', 'Does the distance between Gray Car on the left and the Black Car in the front increase?', 'Can you spot a building in the front?', 'Can you spot a trafficsign in the front that shifts to the right in the later frames due to the camera movement?']
# 2025-02-28 03:02:02,818 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:02:02,820 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "No", "Yes", "Yes", "Yes"]
# 2025-02-28 03:02:02,821 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes']
# 2025-02-28 03:02:02,822 - INFO - Converted answers to binary: [1, 1, 1, 0, 1, 1, 1]
# 2025-02-28 03:02:02,825 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:02:02,826 - INFO - Completed 0002 000000-000009. Answers: ['Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes']
# 2025-02-28 03:02:02,827 - INFO - Binary: [1, 1, 1, 0, 1, 1, 1]
# 2025-02-28 03:02:03,829 - INFO - Processing video 0002, frames 000010-000019
# 2025-02-28 03:02:03,830 - INFO - Questions: ['Can you spot persons on the left of the scene?', 'Are there vehicles on the right of the scene?', 'Are there any poles on the left?']
# 2025-02-28 03:02:03,831 - INFO - Using 5 frames: ['000010.png', '000012.png', '000014.png', '000016.png', '000019.png']
# 2025-02-28 03:02:03,843 - INFO - Sending prompt to Claude with 3 questions: ['Can you spot persons on the left of the scene?', 'Are there vehicles on the right of the scene?', 'Are there any poles on the left?']
# 2025-02-28 03:02:06,058 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:02:06,060 - INFO - Claude's raw response: ["Yes", "Yes", "Yes"]
# 2025-02-28 03:02:06,061 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes']
# 2025-02-28 03:02:06,062 - INFO - Converted answers to binary: [1, 1, 1]
# 2025-02-28 03:02:06,065 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:02:06,065 - INFO - Completed 0002 000010-000019. Answers: ['Yes', 'Yes', 'Yes']
# 2025-02-28 03:02:06,066 - INFO - Binary: [1, 1, 1]
# 2025-02-28 03:02:07,068 - INFO - Processing video 0002, frames 000040-000049
# 2025-02-28 03:02:07,069 - INFO - Questions: ['Are there any vehicles on the right?', 'Is there any White Car that disappear from the left of scene?', 'Is there any Orange Car on the left of the scene?', 'Can you spot a Black Car moving at constant speed on the left of the scene?', 'Is there a pedestrian on the left of the scene?', 'Does the distance between the Black Car on the left and the Black Car in the front increase?']
# 2025-02-28 03:02:07,070 - INFO - Using 5 frames: ['000040.png', '000042.png', '000044.png', '000046.png', '000049.png']
# 2025-02-28 03:02:07,083 - INFO - Sending prompt to Claude with 6 questions: ['Are there any vehicles on the right?', 'Is there any White Car that disappear from the left of scene?', 'Is there any Orange Car on the left of the scene?', 'Can you spot a Black Car moving at constant speed on the left of the scene?', 'Is there a pedestrian on the left of the scene?', 'Does the distance between the Black Car on the left and the Black Car in the front increase?']
# 2025-02-28 03:02:09,822 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:02:09,825 - INFO - Claude's raw response: ["Yes", "No", "No", "Yes", "Yes", "Yes"]
# 2025-02-28 03:02:09,826 - INFO - Successfully parsed answers: ['Yes', 'No', 'No', 'Yes', 'Yes', 'Yes']
# 2025-02-28 03:02:09,827 - INFO - Converted answers to binary: [1, 0, 0, 1, 1, 1]
# 2025-02-28 03:02:09,831 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:02:09,831 - INFO - Completed 0002 000040-000049. Answers: ['Yes', 'No', 'No', 'Yes', 'Yes', 'Yes']
# 2025-02-28 03:02:09,832 - INFO - Binary: [1, 0, 0, 1, 1, 1]
# 2025-02-28 03:02:10,834 - INFO - Processing video 0003, frames 000020-000029
# 2025-02-28 03:02:10,835 - INFO - Questions: ['Is there a White Car on the left?', 'Is there a Red Car on the left?', 'Can you spot a pole on the right?', 'Is the White Car on the left moving?', 'Does the White Car on the left disappear?']
# 2025-02-28 03:02:10,837 - INFO - Using 5 frames: ['000020.png', '000022.png', '000024.png', '000026.png', '000029.png']
# 2025-02-28 03:02:10,850 - INFO - Sending prompt to Claude with 5 questions: ['Is there a White Car on the left?', 'Is there a Red Car on the left?', 'Can you spot a pole on the right?', 'Is the White Car on the left moving?', 'Does the White Car on the left disappear?']
# 2025-02-28 03:02:11,389 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-02-28 03:02:11,391 - INFO - Retrying request to /v1/messages in 29.000000 seconds
# 2025-02-28 03:02:43,321 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:02:43,324 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "No", "No"]
# 2025-02-28 03:02:43,325 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'No', 'No']
# 2025-02-28 03:02:43,326 - INFO - Converted answers to binary: [1, 1, 1, 0, 0]
# 2025-02-28 03:02:43,330 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:02:43,331 - INFO - Completed 0003 000020-000029. Answers: ['Yes', 'Yes', 'Yes', 'No', 'No']
# 2025-02-28 03:02:43,332 - INFO - Binary: [1, 1, 1, 0, 0]
# 2025-02-28 03:02:44,334 - INFO - Processing video 0003, frames 000090-000099
# 2025-02-28 03:02:44,335 - INFO - Questions: ['Is there a Black Car in the front?', 'Is the Black Car in the front moving?', 'Can you spot any pedestrian on the right of the scene?']
# 2025-02-28 03:02:44,336 - INFO - Using 5 frames: ['000090.png', '000092.png', '000094.png', '000096.png', '000099.png']
# 2025-02-28 03:02:44,349 - INFO - Sending prompt to Claude with 3 questions: ['Is there a Black Car in the front?', 'Is the Black Car in the front moving?', 'Can you spot any pedestrian on the right of the scene?']
# 2025-02-28 03:02:46,282 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:02:46,285 - INFO - Claude's raw response: ["Yes", "No", "Yes"]
# 2025-02-28 03:02:46,286 - INFO - Successfully parsed answers: ['Yes', 'No', 'Yes']
# 2025-02-28 03:02:46,287 - INFO - Converted answers to binary: [1, 0, 1]
# 2025-02-28 03:02:46,290 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:02:46,291 - INFO - Completed 0003 000090-000099. Answers: ['Yes', 'No', 'Yes']
# 2025-02-28 03:02:46,292 - INFO - Binary: [1, 0, 1]
# 2025-02-28 03:02:47,294 - INFO - Processing video 0003, frames 000190-000199
# 2025-02-28 03:02:47,295 - INFO - Questions: ['Is there a bicycle on the left?', 'Is there a person on the left?', 'Is there a Black Car near the left?', 'Does the distance between the person and the Black Car on the left increase?', 'Does the Black Car on the left move?']
# 2025-02-28 03:02:47,297 - INFO - Using 5 frames: ['000190.png', '000192.png', '000194.png', '000196.png', '000199.png']
# 2025-02-28 03:02:47,311 - INFO - Sending prompt to Claude with 5 questions: ['Is there a bicycle on the left?', 'Is there a person on the left?', 'Is there a Black Car near the left?', 'Does the distance between the person and the Black Car on the left increase?', 'Does the Black Car on the left move?']
# 2025-02-28 03:02:49,397 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:02:49,399 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "Yes", "No"]
# 2025-02-28 03:02:49,400 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'Yes', 'No']
# 2025-02-28 03:02:49,401 - INFO - Converted answers to binary: [1, 1, 1, 1, 0]
# 2025-02-28 03:02:49,405 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:02:49,406 - INFO - Completed 0003 000190-000199. Answers: ['Yes', 'Yes', 'Yes', 'Yes', 'No']
# 2025-02-28 03:02:49,407 - INFO - Binary: [1, 1, 1, 1, 0]
# 2025-02-28 03:02:50,409 - INFO - Processing video 0004, frames 000000-000009
# 2025-02-28 03:02:50,410 - INFO - Questions: ['Is there a Black Coupe near the left?', 'Doest the Black Coupe disappear from the left of the scene?', 'Is there a White Van at the front?', 'Is the White Van at the front stopped?', 'Does the White Van at the front move at a constant speed?', 'Does the distance between Black Coupe on the left and the White Van in the front decrease?']
# 2025-02-28 03:02:50,411 - INFO - Using 5 frames: ['000000.png', '000002.png', '000004.png', '000006.png', '000009.png']
# 2025-02-28 03:02:50,424 - INFO - Sending prompt to Claude with 6 questions: ['Is there a Black Coupe near the left?', 'Doest the Black Coupe disappear from the left of the scene?', 'Is there a White Van at the front?', 'Is the White Van at the front stopped?', 'Does the White Van at the front move at a constant speed?', 'Does the distance between Black Coupe on the left and the White Van in the front decrease?']
# 2025-02-28 03:02:52,030 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:02:52,032 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "No", "Yes", "Yes"]
# 2025-02-28 03:02:52,033 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes']
# 2025-02-28 03:02:52,034 - INFO - Converted answers to binary: [1, 1, 1, 0, 1, 1]
# 2025-02-28 03:02:52,038 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:02:52,039 - INFO - Completed 0004 000000-000009. Answers: ['Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes']
# 2025-02-28 03:02:52,039 - INFO - Binary: [1, 1, 1, 0, 1, 1]
# 2025-02-28 03:02:53,041 - INFO - Processing video 0004, frames 000140-000149
# 2025-02-28 03:02:53,042 - INFO - Questions: ['Can you spot a Gray Hatchback at the front?', 'Does the Gray Hatchback that is at the front shifts to the near left corner of the scene?', 'Is there any White Van at the front?', 'Does the White Van in the front accelerate?', 'Does the Gray Hatchback move at a constant speed?', 'Does the distance between the White Van in the front and Gray Hatchback increase?', 'Can you see any poles on the left of the scene?', 'Can you see any poles on the right of the scene?']
# 2025-02-28 03:02:53,044 - INFO - Using 5 frames: ['000140.png', '000142.png', '000144.png', '000146.png', '000149.png']
# 2025-02-28 03:02:53,057 - INFO - Sending prompt to Claude with 8 questions: ['Can you spot a Gray Hatchback at the front?', 'Does the Gray Hatchback that is at the front shifts to the near left corner of the scene?', 'Is there any White Van at the front?', 'Does the White Van in the front accelerate?', 'Does the Gray Hatchback move at a constant speed?', 'Does the distance between the White Van in the front and Gray Hatchback increase?', 'Can you see any poles on the left of the scene?', 'Can you see any poles on the right of the scene?']
# 2025-02-28 03:02:53,441 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-02-28 03:02:53,443 - INFO - Retrying request to /v1/messages in 29.000000 seconds
# 2025-02-28 03:03:24,600 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:03:24,602 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "No", "No", "No", "Yes", "Yes"]
# 2025-02-28 03:03:24,603 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes']
# 2025-02-28 03:03:24,604 - INFO - Converted answers to binary: [1, 1, 1, 0, 0, 0, 1, 1]
# 2025-02-28 03:03:24,608 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:03:24,609 - INFO - Completed 0004 000140-000149. Answers: ['Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes']
# 2025-02-28 03:03:24,610 - INFO - Binary: [1, 1, 1, 0, 0, 0, 1, 1]
# 2025-02-28 03:03:25,612 - INFO - Processing video 0005, frames 000780-000789
# 2025-02-28 03:03:25,613 - INFO - Questions: ['Can you spot a Black Truck on the left of the scene?', 'Is the Black Truck on the left stopped?', 'Is the Black Truck on the left moving?', 'Does the Black Truck on the left move at a constant speed?']
# 2025-02-28 03:03:25,614 - INFO - Using 5 frames: ['000780.png', '000782.png', '000784.png', '000786.png', '000789.png']
# 2025-02-28 03:03:25,626 - INFO - Sending prompt to Claude with 4 questions: ['Can you spot a Black Truck on the left of the scene?', 'Is the Black Truck on the left stopped?', 'Is the Black Truck on the left moving?', 'Does the Black Truck on the left move at a constant speed?']
# 2025-02-28 03:03:28,026 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:03:28,028 - INFO - Claude's raw response: ["Yes", "No", "Yes", "Yes"]
# 2025-02-28 03:03:28,029 - INFO - Successfully parsed answers: ['Yes', 'No', 'Yes', 'Yes']
# 2025-02-28 03:03:28,030 - INFO - Converted answers to binary: [1, 0, 1, 1]
# 2025-02-28 03:03:28,034 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:03:28,035 - INFO - Completed 0005 000780-000789. Answers: ['Yes', 'No', 'Yes', 'Yes']
# 2025-02-28 03:03:28,036 - INFO - Binary: [1, 0, 1, 1]
# 2025-02-28 03:03:29,038 - INFO - Processing video 0008, frames 000000-000009
# 2025-02-28 03:03:29,039 - INFO - Questions: ['Is there a Black Wagon on the right of the scene?', 'Does the Black Wagon on the right move at a constant speed?', 'Does a pedestrian appear on the right of the scene?']
# 2025-02-28 03:03:29,040 - INFO - Using 5 frames: ['000000.png', '000002.png', '000004.png', '000006.png', '000009.png']
# 2025-02-28 03:03:29,052 - INFO - Sending prompt to Claude with 3 questions: ['Is there a Black Wagon on the right of the scene?', 'Does the Black Wagon on the right move at a constant speed?', 'Does a pedestrian appear on the right of the scene?']
# 2025-02-28 03:03:31,134 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:03:31,137 - INFO - Claude's raw response: ["Yes", "Yes", "Yes"]
# 2025-02-28 03:03:31,138 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes']
# 2025-02-28 03:03:31,138 - INFO - Converted answers to binary: [1, 1, 1]
# 2025-02-28 03:03:31,142 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:03:31,143 - INFO - Completed 0008 000000-000009. Answers: ['Yes', 'Yes', 'Yes']
# 2025-02-28 03:03:31,144 - INFO - Binary: [1, 1, 1]
# 2025-02-28 03:03:32,147 - INFO - Processing video 0008, frames 000140-000149
# 2025-02-28 03:03:32,148 - INFO - Questions: ['Is there a Blue Van on the left of the scene?', 'Does the speed of the Blue Van remains unchanged?', 'can you spot a White Car in the front of the scene?', 'Does the position of the White car changes from front to left?', 'Does the speed of the White Car remain unchanged?', 'Is there a Black Wagon in the front?', 'Does speed of the Black Wagon in the front remains unchanged?', 'Does the distance between Black Wagon in the front and the Blue Van on the left increase?']
# 2025-02-28 03:03:32,149 - INFO - Using 5 frames: ['000140.png', '000142.png', '000144.png', '000146.png', '000149.png']
# 2025-02-28 03:03:32,160 - INFO - Sending prompt to Claude with 8 questions: ['Is there a Blue Van on the left of the scene?', 'Does the speed of the Blue Van remains unchanged?', 'can you spot a White Car in the front of the scene?', 'Does the position of the White car changes from front to left?', 'Does the speed of the White Car remain unchanged?', 'Is there a Black Wagon in the front?', 'Does speed of the Black Wagon in the front remains unchanged?', 'Does the distance between Black Wagon in the front and the Blue Van on the left increase?']
# 2025-02-28 03:03:34,206 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:03:34,208 - INFO - Claude's raw response: ["Yes", "No", "Yes", "No", "No", "No", "No", "Yes"]
# 2025-02-28 03:03:34,209 - INFO - Successfully parsed answers: ['Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes']
# 2025-02-28 03:03:34,210 - INFO - Converted answers to binary: [1, 0, 1, 0, 0, 0, 0, 1]
# 2025-02-28 03:03:34,213 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:03:34,214 - INFO - Completed 0008 000140-000149. Answers: ['Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes']
# 2025-02-28 03:03:34,215 - INFO - Binary: [1, 0, 1, 0, 0, 0, 0, 1]
# 2025-02-28 03:03:35,216 - INFO - Processing video 0010, frames 000000-000009
# 2025-02-28 03:03:35,217 - INFO - Questions: ['Is there a Red Car in the front that moves to the right of the scene?', 'Is there a White Car on the left of the scene?', 'Can you spot a Blue Car in the front?', 'Does the White Car on the left move at a constant speed?', 'Does the distance between White Car and the Red Car increase?', 'Can you spot a White Car in the front?']
# 2025-02-28 03:03:35,218 - INFO - Using 5 frames: ['000000.png', '000002.png', '000004.png', '000006.png', '000009.png']
# 2025-02-28 03:03:35,229 - INFO - Sending prompt to Claude with 6 questions: ['Is there a Red Car in the front that moves to the right of the scene?', 'Is there a White Car on the left of the scene?', 'Can you spot a Blue Car in the front?', 'Does the White Car on the left move at a constant speed?', 'Does the distance between White Car and the Red Car increase?', 'Can you spot a White Car in the front?']
# 2025-02-28 03:03:35,752 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 429 Too Many Requests"
# 2025-02-28 03:03:35,753 - INFO - Retrying request to /v1/messages in 28.000000 seconds
# 2025-02-28 03:04:05,867 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:04:05,870 - INFO - Claude's raw response: ["Yes", "Yes", "Yes", "Yes", "Yes", "No"]
# 2025-02-28 03:04:05,871 - INFO - Successfully parsed answers: ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# 2025-02-28 03:04:05,871 - INFO - Converted answers to binary: [1, 1, 1, 1, 1, 0]
# 2025-02-28 03:04:05,875 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:04:05,876 - INFO - Completed 0010 000000-000009. Answers: ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# 2025-02-28 03:04:05,877 - INFO - Binary: [1, 1, 1, 1, 1, 0]
# 2025-02-28 03:04:06,879 - INFO - Processing video 0012, frames 000000-000009
# 2025-02-28 03:04:06,880 - INFO - Questions: ['Is there a White Car on the right of the scene?']
# 2025-02-28 03:04:06,881 - INFO - Using 5 frames: ['000000.png', '000002.png', '000004.png', '000006.png', '000009.png']
# 2025-02-28 03:04:06,893 - INFO - Sending prompt to Claude with 1 questions: ['Is there a White Car on the right of the scene?']
# 2025-02-28 03:04:08,536 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-02-28 03:04:08,538 - INFO - Claude's raw response: ["Yes"]
# 2025-02-28 03:04:08,538 - INFO - Successfully parsed answers: ['Yes']
# 2025-02-28 03:04:08,539 - INFO - Converted answers to binary: [1]
# 2025-02-28 03:04:08,543 - INFO - Saved progress to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
# 2025-02-28 03:04:08,544 - INFO - Completed 0012 000000-000009. Answers: ['Yes']
# 2025-02-28 03:04:08,545 - INFO - Binary: [1]
# 2025-02-28 03:04:09,549 - INFO - All processing complete. Results saved to /home/ibk5106/projects/projects/LogicRAG/tools/kb_framework/kitti_questions/all_que_fn_model_ans.csv
